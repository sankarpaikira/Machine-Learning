# %% [markdown]
# # Ice-Cream Dataset Model - linear data

# %% [markdown]
# ## Loading Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("filename.csv")
df.head()

# %% [markdown]
# ## Data Cleaning

# %%
df.info()

# %%
df.dtypes

# %%
df.drop_duplicates()

# %%
df.isnull().count()

# %% [markdown]
# ### Data Splitting in to X and y

# %%
y = df["last_col_name"]
X = df.drop("last_col_name", axis = 1) # axis = 1 column wise 1 column after other column
